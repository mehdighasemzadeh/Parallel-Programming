# %%
# !git clone https://github.com/mehdighasemzadeh/Parallel-Programming.git
# Out:
# Cloning into 'Parallel-Programming'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 38 (delta 5), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (38/38), 18.39 KiB | 2.04 MiB/s, done.

# %%
# %cd /content/Parallel-Programming
# %cd multiply
# !nvcc -O2 bmm_main.cu bmm.cu -o bmm
# !./bmm 10
# Out:
# /content/Parallel-Programming
# /content/Parallel-Programming/multiply
# Device Name: Tesla T4
# m=10 n=1024 GPU=154.3 ms GPU-Kernel=5.6135 ms mse=0

# %%
# %cd /content/Parallel-Programming
# %cd scan
# !nvcc scan2.cu scan2_main.cu -o scan2
# !./scan2 20
# Out:
# /content/Parallel-Programming
# /content/Parallel-Programming/scan
# n=1048576	 time=000684 ms mse=0.000000

# %%
# %cd /content/Parallel-Programming
# %cd FFT
# !nvcc -O2 fft_main.cu fft.cu -o fft
# !./fft 10
# Out:
# /content/Parallel-Programming
# /content/Parallel-Programming/FFT
# Device Name: Tesla T4
# m=10 n=1024 CPU=0.159 ms GPU=157.409 ms GPU-Kernels=0.303072 ms mse=6.12827e-10

# %%
# %cd /content/Parallel-Programming
# %cd merge-sort
# !gcc -O2 pth_msort_test.c pth_msort.c -lpthread -lm
# !./a.out 20
# Out:
# /content/Parallel-Programming
# /content/Parallel-Programming/merge-sort
# Runtime= 0.0829949 s N=1048576
